# %%
# !pip install dvc["s3"]
# !pip install pycaret

# %%
# %cd drive/MyDrive/Colab\ Notebooks/MLOps_Final_Assignment
# Out:
# /content/drive/MyDrive/Colab Notebooks/MLOps_Final_Assignment

# %%
import mlflow

# %%
import pandas as pd
import numpy as np
from pycaret.classification import *

data = pd.read_csv("data/creditcard.csv")
data_unseen = data.sample(frac = 0.1, random_state = 42)
data = data.drop(data_unseen.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print("Train + Val -", data.shape, "\nTest -", data_unseen.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# Train + Val - (256326, 31)
# Test - (28481, 31)

# %%
expt_basic = setup(
    data = data, 
    target = 'Class',
    session_id=42,
    train_size=0.8,
    numeric_imputation="median",
    categorical _imputation="mode",
    fix_imbalance=True,
    log_experiment = True,
    log_plots = True,
    log_data = True,
    experiment_name = "First"
)
# Out:
#                                Description            Value
# 0                               session_id               42
# 1                                   Target            Class
# 2                              Target Type           Binary
# 3                            Label Encoded       0: 0, 1: 1
# 4                            Original Data     (256326, 31)
# 5                           Missing Values            False
# 6                         Numeric Features               30
# 7                     Categorical Features                0
# 8                         Ordinal Features            False
# 9                High Cardinality Features            False
# 10                 High Cardinality Method             None
# 11                   Transformed Train Set     (205060, 30)
# 12                    Transformed Test Set      (51266, 30)
# 13                      Shuffle Train-Test             True
# 14                     Stratify Train-Test            False
# ...

# %%
models()
# Out:
#                                      Name  ...  Turbo
# ID                                         ...
# lr                    Logistic Regression  ...   True
# knn                K Neighbors Classifier  ...   True
# nb                            Naive Bayes  ...   True
# dt               Decision Tree Classifier  ...   True
# svm                   SVM - Linear Kernel  ...   True
# rbfsvm                SVM - Radial Kernel  ...  False
# gpc           Gaussian Process Classifier  ...  False
# mlp                        MLP Classifier  ...  False
# ridge                    Ridge Classifier  ...   True
# rf               Random Forest Classifier  ...   True
# qda       Quadratic Discriminant Analysis  ...   True
# ada                  Ada Boost Classifier  ...   True
# gbc          Gradient Boosting Classifier  ...   True
# lda          Linear Discriminant Analysis  ...   True
# et                 Extra Trees Classifier  ...   True
# ...

# %%
best_classifier = compare_models(sort="F1", fold = 5, n_select = 5)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.9995  0.9679  0.8157  0.8856
# rf               Random Forest Classifier    0.9994  0.9556  0.8043  0.8637
# lightgbm  Light Gradient Boosting Machine    0.9991  0.9553  0.8157  0.6988
# dt               Decision Tree Classifier    0.9976  0.8743  0.7506  0.3983
# gbc          Gradient Boosting Classifier    0.9944  0.9731  0.8639  0.2183
# nb                            Naive Bayes    0.9922  0.9639  0.7447  0.1493
# ada                  Ada Boost Classifier    0.9878  0.9727  0.8753  0.1122
# ridge                    Ridge Classifier    0.9883  0.0000  0.8158  0.1107
# lda          Linear Discriminant Analysis    0.9883  0.9684  0.8158  0.1107
# svm                   SVM - Linear Kernel    0.9636  0.0000  0.5945  0.1288
# lr                    Logistic Regression    0.9782  0.9636  0.8838  0.0694
# ...

# %%
# %cd models
# Out:
# /content/drive/My Drive/Colab Notebooks/MLOps_Final_Assignment/models

# %%
for i in range(5):
  save_model(best_classifier[i], str(i))
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved

# %%
for i in range(0, 1):
  z_tuned = tune_model(best_classifier[i], fold = 5, optimize = 'F1')
  save_model(z_tuned, str(i)+'_tuned')

# Extra Trees
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9991  0.9733  0.7571  0.7260  0.7413  0.7408  0.7410
# 1       0.9989  0.9524  0.8286  0.6444  0.7250  0.7245  0.7302
# 2       0.9991  0.9621  0.8169  0.7160  0.7632  0.7627  0.7644
# 3       0.9990  0.9940  0.9014  0.6598  0.7619  0.7614  0.7708
# 4       0.9992  0.9655  0.8169  0.7632  0.7891  0.7887  0.7892
# Mean    0.9991  0.9695  0.8242  0.7019  0.7561  0.7556  0.7591
# SD      0.0001  0.0140  0.0460  0.0438  0.0217  0.0218  0.0211
# Transformation Pipeline and Model Successfully Saved

# %%
for i in range(4, 5):
  z_tuned = tune_model(best_classifier[i], fold = 5, optimize = 'F1')
  save_model(z_tuned, str(i)+'_tuned')

# SVM - Linear Kernel
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9989  0.9338  0.7429  0.6420  0.6887  0.6882  0.6900
# 1       0.9990  0.9578  0.8143  0.6628  0.7308  0.7303  0.7341
# 2       0.9979  0.9351  0.7606  0.4426  0.5596  0.5586  0.5793
# 3       0.9987  0.9156  0.8310  0.5784  0.6821  0.6814  0.6927
# 4       0.9990  0.9347  0.8028  0.6951  0.7451  0.7446  0.7466
# Mean    0.9987  0.9354  0.7903  0.6042  0.6813  0.6806  0.6885
# SD      0.0004  0.0134  0.0332  0.0893  0.0654  0.0656  0.0590
# Transformation Pipeline and Model Successfully Saved

# %%
for i in range(3, 4):
  z_tuned = tune_model(best_classifier[i], fold = 5, optimize = 'F1')
  save_model(z_tuned, str(i)+'_tuned')

# Decision Tree
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9921  0.9263  0.8286  0.1563  0.2630  0.2609  0.3579
# 1       0.9932  0.9144  0.8429  0.1815  0.2987  0.2968  0.3894
# 2       0.9929  0.8846  0.8028  0.1696  0.2801  0.2780  0.3671
# 3       0.9924  0.9550  0.9155  0.1752  0.2941  0.2921  0.3987
# 4       0.9936  0.9621  0.8732  0.1975  0.3221  0.3202  0.4135
# Mean    0.9928  0.9285  0.8526  0.1760  0.2916  0.2896  0.3853
# SD      0.0006  0.0281  0.0388  0.0136  0.0197  0.0197  0.0204
# Transformation Pipeline and Model Successfully Saved

# %%
dt = load_model('3_tuned')
lgbm = load_model('2_tuned')
et = load_model('0_tuned')
gbc = load_model('4_tuned')
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(et);
predict_model(dt);
predict_model(lgbm); # Best F1 score and accuracy.
predict_model(gbc);
# Out:
#                     Model  Accuracy     AUC  ...   F1   Kappa     MCC
# 0  Extra Trees Classifier    0.9993  0.9826  ...  0.8  0.7996  0.7998
#
# [1 rows x 8 columns]
#                       Model  Accuracy     AUC  ...      F1   Kappa     MCC
# 0  Decision Tree Classifier    0.9922  0.9444  ...  0.2888  0.2866  0.3863
#
# [1 rows x 8 columns]
#                              Model  Accuracy     AUC  ...     F1   Kappa     MCC
# 0  Light Gradient Boosting Machine    0.9996  0.9865  ...  0.877  0.8768  0.8768
#
# [1 rows x 8 columns]
#                           Model  Accuracy     AUC  ...     F1   Kappa     MCC
# 0  Gradient Boosting Classifier     0.998  0.9577  ...  0.616  0.6151  0.6434
#
# [1 rows x 8 columns]

# %%
from pycaret.utils import check_metric

pred_unseen = predict_model(lgbm, data = data_unseen)
print("Accuracy\t", check_metric(pred_unseen.Class, pred_unseen.Label, 'Accuracy'))
print("F1\t\t", check_metric(pred_unseen.Class, pred_unseen.Label, 'F1'))
print("Recall\t\t", check_metric(pred_unseen.Class, pred_unseen.Label, 'Recall'))
print("Precision\t", check_metric(pred_unseen.Class, pred_unseen.Label, 'Precision'))
# Out:
# Accuracy	 0.9995
# F1		 0.8444
# Recall		 0.8261
# Precision	 0.8636

# %%
lgbm_untuned = load_model('2')
print(lgbm_untuned)
final_model = finalize_model(lgbm_untuned)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='Class',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='most frequent',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strateg...
#                  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
# ...

# %%
final_model = finalize_model(lgbm)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-0328b82e531c> in <module>()
# ----> 1 final_model = finalize_model(lgbm)
#
# /usr/local/lib/python3.7/dist-packages/pycaret/classification.py in finalize_model(estimator, fit_kwargs, groups, model_only)
#    2007         fit_kwargs=fit_kwargs,
#    2008         groups=groups,
# -> 2009         model_only=model_only,
#    2010     )
#    2011
#
# /usr/local/lib/python3.7/dist-packages/pycaret/internal/tabular.py in finalize_model(estimator, fit_kwargs, groups, model_only, display)
#    8736         y_train_data=y,
#    8737         fit_kwargs=fit_kwargs,
# -> 8738         groups=groups,
#    8739     )
#    8740     model_results = pull(pop=True)
#
# ...
